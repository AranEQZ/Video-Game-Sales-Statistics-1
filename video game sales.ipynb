# %%
# # Load the necessary packages
import pandas as pd
import numpy as np

# %%
mydata = pd.read_csv('vgsales.csv')

# %%
mydata.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
mydata = pd.read_csv('vgsales.csv')

# %%
# mydata.head()
# mydata.columns
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
mydata.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Rank", y="Global_Sales", data=mydata)
# Out:
# <Axes: xlabel='Rank', ylabel='Global_Sales'>

# %%
pd.crosstab(mydata['Rank'],mydata['Genre'] )
# Out:
# Genre  Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Rank
# 1           0          0         0     0         0       0       0
# 2           0          0         0     0         1       0       0
# 3           0          0         0     0         0       0       1
# 4           0          0         0     0         0       0       0
# 5           0          0         0     0         0       0       0
# ...       ...        ...       ...   ...       ...     ...     ...
# 16596       0          0         0     0         1       0       0
# 16597       0          0         0     0         0       0       0
# 16598       0          0         0     0         0       0       1
# 16599       0          0         0     0         0       1       0
# 16600       0          0         0     0         1       0       0
#
# Genre  Role-Playing  Shooter  Simulation  Sports  Strategy
# Rank
# 1                 0        0           0       1         0
# ...

# %%
pd.crosstab(mydata['Name'],mydata['Publisher'] )
# Out:
# Publisher                                10TACLE Studios  1C Company  \
# Name
# '98 Koshien                                            0           0
# .hack//G.U. Vol.1//Rebirth                             0           0
# .hack//G.U. Vol.2//Reminisce                           0           0
# .hack//G.U. Vol.2//Reminisce (jp sales)                0           0
# .hack//G.U. Vol.3//Redemption                          0           0
# ...                                                  ...         ...
# thinkSMART FAMILY!                                     0           0
# thinkSMART: Chess for Kids                             0           0
# uDraw Studio                                           0           0
# uDraw Studio: Instant Artist                           0           0
# ¡Shin Chan Flipa en colores!                           0           0
#
# Publisher                                20th Century Fox Video Games  2D Boy  \
# Name
# ...

# %%
sns.countplot(x="Genre", hue="Global_Sales", data=mydata)
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['Name', 'Genre'],
                     columns=[ 'Global_Sales'], aggfunc=len)
# Out:
#                                                      EU_Sales              \
# Global_Sales                                            0.01  0.02  0.03
# Name                                    Genre
# '98 Koshien                             Sports            NaN   NaN   NaN
# .hack//G.U. Vol.1//Rebirth              Role-Playing      NaN   NaN   NaN
# .hack//G.U. Vol.2//Reminisce            Role-Playing      NaN   NaN   NaN
# .hack//G.U. Vol.2//Reminisce (jp sales) Role-Playing      NaN   NaN   NaN
# .hack//G.U. Vol.3//Redemption           Role-Playing      NaN   NaN   NaN
# ...                                                       ...   ...   ...
# thinkSMART: Chess for Kids              Misc              1.0   NaN   NaN
# uDraw Studio                            Misc              NaN   NaN   NaN
# uDraw Studio: Instant Artist            Misc              NaN   1.0   NaN
# wwe Smackdown vs. Raw 2006              Fighting          NaN   NaN   NaN
# ...

# %%
pd.pivot_table(mydata,'Rank', index=['Platform', 'Year'],
                     columns=[ 'Global_Sales'])
# Out:
# Global_Sales            0.01          0.02          0.03          0.04   \
# Platform Year
# 2600     1980.0           NaN           NaN           NaN           NaN
#          1981.0           NaN           NaN           NaN           NaN
#          1982.0           NaN           NaN           NaN           NaN
#          1983.0           NaN           NaN           NaN           NaN
#          1984.0           NaN           NaN           NaN           NaN
# ...                       ...           ...           ...           ...
# XB       2008.0           NaN           NaN           NaN           NaN
# XOne     2013.0           NaN           NaN           NaN           NaN
#          2014.0  16312.500000           NaN  14763.000000  13863.500000
#          2015.0  16244.000000  15552.750000  14502.500000  13892.500000
#          2016.0  16463.333333  15341.333333  14513.666667  13751.571429
#
# Global_Sales        0.05     0.06     0.07     0.08     0.09     0.10   ...  \
# ...

# %%
mydata['Global_Sales'].std()
# Out:
# np.float64(1.5550279355699124)

# %%
mydata['Global_Sales'].mean()
# Out:
# np.float64(0.5374406555006628)

# %%
sns.displot(mydata['Global_Sales'])

# %%
mydata.hist(by='Year',column = 'Global_Sales')
# Out:
# array([[<Axes: title={'center': '1980.0'}>,
#         <Axes: title={'center': '1981.0'}>,
#         <Axes: title={'center': '1982.0'}>,
#         <Axes: title={'center': '1983.0'}>,
#         <Axes: title={'center': '1984.0'}>,
#         <Axes: title={'center': '1985.0'}>],
#        [<Axes: title={'center': '1986.0'}>,
#         <Axes: title={'center': '1987.0'}>,
#         <Axes: title={'center': '1988.0'}>,
#         <Axes: title={'center': '1989.0'}>,
#         <Axes: title={'center': '1990.0'}>,
#         <Axes: title={'center': '1991.0'}>],
#        [<Axes: title={'center': '1992.0'}>,
#         <Axes: title={'center': '1993.0'}>,
#         <Axes: title={'center': '1994.0'}>,
#         <Axes: title={'center': '1995.0'}>,
#         <Axes: title={'center': '1996.0'}>,
#         <Axes: title={'center': '1997.0'}>],
#        [<Axes: title={'center': '1998.0'}>,
#         <Axes: title={'center': '1999.0'}>,
#         <Axes: title={'center': '2000.0'}>,
# ...

# %%
mydata.hist(by='Genre',column = 'Publisher')
# Out:
# array([[<Axes: title={'center': 'Action'}>,
#         <Axes: title={'center': 'Adventure'}>,
#         <Axes: title={'center': 'Fighting'}>],
#        [<Axes: title={'center': 'Misc'}>,
#         <Axes: title={'center': 'Platform'}>,
#         <Axes: title={'center': 'Puzzle'}>],
#        [<Axes: title={'center': 'Racing'}>,
#         <Axes: title={'center': 'Role-Playing'}>,
#         <Axes: title={'center': 'Shooter'}>],
#        [<Axes: title={'center': 'Simulation'}>,
#         <Axes: title={'center': 'Sports'}>,
#         <Axes: title={'center': 'Strategy'}>]], dtype=object)

# %%
mydata.hist(by='Genre',column = 'Global_Sales')
# Out:
# array([[<Axes: title={'center': 'Action'}>,
#         <Axes: title={'center': 'Adventure'}>,
#         <Axes: title={'center': 'Fighting'}>],
#        [<Axes: title={'center': 'Misc'}>,
#         <Axes: title={'center': 'Platform'}>,
#         <Axes: title={'center': 'Puzzle'}>],
#        [<Axes: title={'center': 'Racing'}>,
#         <Axes: title={'center': 'Role-Playing'}>,
#         <Axes: title={'center': 'Shooter'}>],
#        [<Axes: title={'center': 'Simulation'}>,
#         <Axes: title={'center': 'Sports'}>,
#         <Axes: title={'center': 'Strategy'}>]], dtype=object)

# %%
sns.pairplot(mydata)
